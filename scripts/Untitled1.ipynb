# %%
import pandas as pd

# %%
df = pd.read_pickle('biophys.pkl')

# %%
df.head()
# Out:
#                   unique_id  DNA  chromatin  cells  Hi-C  nucleosome  \
# 0  5eaa048b9b21ead543e41731  7.0        7.0    1.0   1.0         1.0
# 1  5eaa048f9b21ead543e4177a  NaN        NaN    6.0   NaN         NaN
# 2  5eaa048f9b21ead543e4178d  NaN        NaN    NaN   NaN         NaN
# 3  5eaa048f9b21ead543e4178e  1.0        NaN    NaN   NaN         NaN
# 4  5eaa048f9b21ead543e4178f  NaN        NaN    NaN   NaN         NaN
#
#    partially-methylated-domain  non-partially-methylated-domain  cell  \
# 0                          1.0                              1.0   NaN
# 1                          NaN                              NaN   4.0
# 2                          NaN                              NaN   NaN
# 3                          NaN                              NaN   NaN
# 4                          NaN                              NaN   NaN
#
#    chromosomes  ...  ligand-specific  diazirine moieties  3-hydroxyl  KK148  \
# ...
